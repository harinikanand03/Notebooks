# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import save_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
from random import randint

# %% [markdown]
# Reference: https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/

# %%
imagefl = [
"Plastic Straws108.jpg",
"Plastic Straws134.jpg",
"Plastic Straws88.jpg",
"Plastic Straws120.jpg",
"Plastic Straws63.jpg",
"Plastic Straws77.jpg",
"Plastic Straws1506.jpg",
"Plastic Straws478.jpg",
"Plastic Straws322.jpg",
"Plastic Straws444.jpg",
"Plastic Straws487.jpg",
"Plastic Straws518.jpg",
"Plastic Straws3271.jpg",
"Plastic Straws5614.jpg",
"Plastic Straws524.jpg",
"Plastic Straws242.jpg",
"Plastic Straws256.jpg",
"Plastic Straws2806.jpg",
"Plastic Straws295.jpg",
"Plastic Straws1116.jpg",
"Plastic Straws5416.jpg",
"Plastic Straws2351.jpg",
"Plastic Straws1894.jpg",
"Plastic Straws1895.jpg",
"Plastic Straws2350.jpg",
"Plastic Straws1117.jpg",
"Plastic Straws5417.jpg",
"Plastic Straws294.jpg",
"Plastic Straws280.jpg",
"Plastic Straws2807.jpg",
"Plastic Straws3258.jpg",
"Plastic Straws531.jpg",
"Plastic Straws525.jpg",
"Plastic Straws243.jpg",
"Plastic Straws5615.jpg",
"Plastic Straws519.jpg",
"Plastic Straws3270.jpg",
"Plastic Straws486.jpg",
"Plastic Straws492.jpg",
"Plastic Straws323.jpg",
"Plastic Straws445.jpg",
"Plastic Straws1507.jpg",
"Plastic Straws479.jpg",
"Plastic Straws76.jpg",
"Plastic Straws62.jpg",
"Plastic Straws89.jpg",
"Plastic Straws121.jpg",
"Plastic Straws109.jpg",
"Plastic Straws123.jpg",
"Plastic Straws137.jpg",
"Plastic Straws74.jpg",
"Plastic Straws60.jpg",
"Plastic Straws48.jpg",
"Plastic Straws1505.jpg",
"Plastic Straws309.jpg",
"Plastic Straws321.jpg",
"Plastic Straws484.jpg",
"Plastic Straws269.jpg",
"Plastic Straws5617.jpg",
"Plastic Straws3272.jpg",
"Plastic Straws533.jpg",
"Plastic Straws255.jpg",
"Plastic Straws241.jpg",
"Plastic Straws2805.jpg",
"Plastic Straws282.jpg",
"Plastic Straws5415.jpg",
"Plastic Straws1115.jpg",
"Plastic Straws1897.jpg",
"Plastic Straws2352.jpg",
"Plastic Straws2353.jpg",
]

# %% [markdown]
# Set up Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Read and Write folder paths

# %%
rawfilepath = 'gdrive/My Drive/Colab Notebooks/MSDS-462/Datasets/Images/plasticstraws/'
augfilepath = rawfilepath +'augmented/'

# %%
rawfilepath
# Out:
# 'gdrive/My Drive/Colab Notebooks/MSDS-462/Datasets/Images/plasticstraws/'

# %%
augfilepath
# Out:
# 'gdrive/My Drive/Colab Notebooks/MSDS-462/Datasets/Images/plasticstraws/augmented/'

# %% [markdown]
# How many images to augment?

# %%
imagefl_len = len(imagefl)
imagefl_len
# Out:
# 70

# %%
filestoaug = 20

# %%
for i in range(filestoaug):
  randn = randint(0,(imagefl_len-1))
  print('Processing file '+str(i+1)+' out of '+str(filestoaug))
  filename=imagefl[randn]
  img = load_img(rawfilepath+imagefl[randn])

  # convert to numpy array
  data = img_to_array(img)

  # expand dimension to one sample
  samples = expand_dims(data, 0)

  # ImageDataGenerator
  datagen = ImageDataGenerator(
    rotation_range=10, # rotation
    width_shift_range=0.4, # horizontal shift
    height_shift_range=0.4, # vertical shift
    zoom_range=0.3, # zoom
    horizontal_flip=True, # horizontal flip
    brightness_range=[0.1,1.5]) # brightness

  # iterator
  it = datagen.flow(samples, batch_size=1)

  # generate samples and plot
  for i in range(9):
    # define subplot
    pyplot.subplot(330 + 1 + i)
    # generate batch of images
    batch = it.next()
    # convert to unsigned integers for viewing
    image = batch[0].astype('uint8')
    # plot raw pixel data
    pyplot.imshow(image)
    filename=filename[:-4]

    save_img(augfilepath+filename+'augmented'+str(i)+'.jpg',image)
    # show the figure
    pyplot.show()
# Out:
# Processing file 1 out of 20
# Processing file 2 out of 20
# Processing file 3 out of 20
# Processing file 4 out of 20
# Processing file 5 out of 20
# Processing file 6 out of 20
# Processing file 7 out of 20
# Processing file 8 out of 20
# Processing file 9 out of 20
# Processing file 10 out of 20
# Processing file 11 out of 20
# Processing file 12 out of 20
# Processing file 13 out of 20
# Processing file 14 out of 20
# Processing file 15 out of 20
# Processing file 16 out of 20
# Processing file 17 out of 20
# Processing file 18 out of 20
# Processing file 19 out of 20
# Processing file 20 out of 20
